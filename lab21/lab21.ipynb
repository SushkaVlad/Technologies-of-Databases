# %%
import numpy as np
import pandas as pd 
import math

import matplotlib.pyplot as plt
from matplotlib.patches import Ellipse
import matplotlib.transforms as transforms

# %%
table = pd.read_csv(r'D:\Рабочий стол\8 сем\Специальные технологии баз данных\movement_libras.dat',sep=',')
table
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17288/1633431628.py in <module>
# ----> 1 table = pd.read_csv(r'D:\Рабочий стол\8 сем\Специальные технологии баз данных\movement_libras.dat',sep=',')
#       2 table
#
# C:\anac\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
a = table.columns[:-1]
b = a.copy()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17288/2388757359.py in <module>
# ----> 1 a = table.columns[:-1]
#       2 b = a.copy()
#
# NameError: name 'table' is not defined

# %%
from sklearn import preprocessing
scaler_std = preprocessing.StandardScaler()
for i in a:
    x = scaler_std.fit_transform(table[a])
    table[a] = x[0:]
table
# Out:
#      1st_coordinate_abcissa   1st_coordinate_ordinate  \
# 0                  1.159373                 -0.929510
# 1                  0.565381                 -1.510578
# 2                  0.779589                 -1.708416
# 3                 -0.009128                 -1.238605
# 4                  0.526416                 -0.917119
# ..                      ...                       ...
# 355                0.467968                  1.258935
# 356                0.370606                  0.875651
# 357                0.224562                  1.085827
# 358                0.467968                  1.258935
# 359                0.370606                  0.875651
#
#       2st_coordinate_abcissa   2st_coordinate_ordinate  \
# 0                   1.164132                 -0.952467
# 1                   0.578060                 -1.509295
# 2                   0.792926                 -1.707307
# 3                  -0.017759                 -1.237082
# ...

# %%
table_old = table.copy()

# %%
table = table.drop(table.columns[-1],axis=1)

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components = 10)

table_train = pca.fit_transform(table)

explained_variance = pca.explained_variance_
explained_variance_ratio = pca.explained_variance_ratio_
print(explained_variance)
print(explained_variance_ratio)
print(explained_variance_ratio.sum())
# Out:
# [21.11374555 18.9491506  16.12252029 11.6711225   5.51957859  5.3301308
#   2.98187609  2.4661225   1.95631178  1.56474463]
# [0.23394551 0.20996127 0.17864151 0.12931892 0.06115829 0.05905917
#  0.03303992 0.02732525 0.02167642 0.01733776]
# 0.9714640090835827

# %%
#критерий Кайзера
ev = []
for i in explained_variance:
    if i > 1:
        ev.append(i)
ev
# Out:
# [21.113745547562765,
#  18.949150603437495,
#  16.122520286259373,
#  11.671122495708962,
#  5.519578592149646,
#  5.330130801480267,
#  2.9818760866608285,
#  2.466122504588583,
#  1.9563117839152686]

# %%
#главные компоненты
pca = PCA(n_components = 10)

table_train = pca.fit_transform(table)
comp = pca.components_
comp.T
# Out:
# array([[-0.13100049,  0.06285489, -0.14701312,  0.02613117, -0.08934272,
#         -0.02504454, -0.03837379,  0.21565168,  0.06882541, -0.05686256],
#        [-0.16883043, -0.05836495,  0.09357332,  0.01099404,  0.02850527,
#         -0.01056507, -0.22729381, -0.00951522,  0.01874142,  0.04644548],
#        [-0.13101386,  0.0633448 , -0.14727996,  0.02597959, -0.0883554 ,
#         -0.02444071, -0.03858449,  0.21605845,  0.07154317, -0.05626935],
#        [-0.16894926, -0.05771133,  0.09371837,  0.01107891,  0.02773559,
#         -0.01090952, -0.22944881, -0.0099894 ,  0.01873702,  0.04746837],
#        [-0.13080585,  0.06406005, -0.14820519,  0.02530775, -0.08601821,
#         -0.02433254, -0.03799102,  0.21715678,  0.07447836, -0.05525199],
#        [-0.16920394, -0.05726793,  0.09378678,  0.01068541,  0.02923245,
#         -0.01045066, -0.23054395, -0.0102133 ,  0.02018417,  0.04877105],
#        [-0.13028915,  0.0653034 , -0.14977619,  0.02573305, -0.08150645,
# ...

# %%
from sklearn import tree
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
train_table, test_table = train_test_split(table_old, test_size= 0.4, random_state=42)
train_table

# %%
clf = tree.DecisionTreeClassifier(criterion = 'entropy')

# %%
clf.fit(train_table.drop(train_table.columns[-1],axis=1),train_table[[' class']])
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
clf.score(test_table.drop(test_table.columns[-1],axis=1),test_table[[' class']])
# Out:
# 0.7013888888888888
